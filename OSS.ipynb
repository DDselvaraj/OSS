# %% [markdown]
# <a href="https://colab.research.google.com/github/DDselvaraj/OSS/blob/main/OSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel('/content/bmi.xlsx')
df.head()
# Out:
#    Gender  Height  Weight        BMI  Status
# 0  Female     166     144  52.257222       5
# 1  Female     188     115  32.537347       4
# 2  Female     155     111  46.201873       5
# 3  Female     185     119  34.769905       4
# 4    Male     149      61  27.476240       3

# %%
table=pd.pivot_table(data=df,index=['BMI','Gender'],values='Status')
table
# Out:
#                   Status
# BMI       Gender
# 16.376279 Female       1
# 16.995148 Male         1
# 17.432851 Female       1
# 17.961266 Male         1
# 18.145957 Male         1
# ...                  ...
# 68.407022 Female       5
# 68.962282 Female       5
# 70.763331 Male         5
# 71.927971 Female       5
# 78.853402 Female       5
#
# [100 rows x 1 columns]

# %%
df.memory_usage(deep=True)
# Out:
# Index      128
# Gender    6202
# Height     800
# Weight     800
# BMI        800
# Status     800
# dtype: int64

# %%
df['Status'].value_counts()
# Out:
# 5    48
# 4    26
# 3    12
# 2     8
# 1     6
# Name: Status, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
height = np.asarray(df.Height)
weight = np.asarray(df.Weight)
bmi= np.asarray(df.BMI)
plt.scatter(x=height, y=weight, s=bmi * 2)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height Vs Weight')
plt.show()

# %%
print('The mean of weights in the dataset is:',df['Weight'].mean())
print('The maximum BMI in the dataset is:',df['BMI'].max())
print('The minimum BMI in the dataset is:',df['BMI'].min())
print('The total sum of BMI in the dataset is:',df['BMI'].sum())
# Out:
# The mean of weights in the dataset is: 114.69
# The maximum BMI in the dataset is: 78.85340210275739
# The minimum BMI in the dataset is: 16.376278557813635
# The total sum of BMI in the dataset is: 4108.5363665547175

# %%
plt.bar(df.Status,df.BMI,color='maroon',width=0.5)
plt.xlabel('Status')
plt.ylabel('BMI')
plt.title('BMI of people w.r.t Status')
plt.show()

# %%
plt.scatter(df.Status,df.BMI,color= "green",marker= "*", s=30)
plt.xlabel('Status')
plt.ylabel('BMI')
plt.title('BMI of people w.r.t Status')
# Out:
# Text(0.5, 1.0, 'BMI of people w.r.t Status')

# %%
plt.plot(df.Height,df.Weight, "o")
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height vs Weight Graph')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
low = (0, 1, 0)
medium = (1, 1, 0)
high = (1, 0, 0)
height_t = np.asarray([152,155,160,163,173,178,180,183,188,190])
weight_t= np.asarray([40,40,60,63,55,78,80,60,88,60])
bmi_t = np.asarray([17.3,16.6,23.4,23.7,18.4,24.6,24.7,17.9,24.9,16.6])
status_t =[medium,low,high,high,medium,high,high,medium,high,low] 
height_h = np.asarray([152,155,160,163,173,178,180,183,188,190])
weight_h= np.asarray([60,75,60,63,85,78,80,105,88,110])
bmi_h = np.asarray([26,31.2,23.4,23.7,28.4,24.6,24.7,31.4,24.9,30.5])
status_h =[medium,high,low,low,high,medium,medium,high,medium,high]
plt.scatter(
    x=height_t,
    y=weight_t,
    s=bmi_t * 10,
    c=status_t,
    cmap="jet",
    alpha=0.5,
)
plt.scatter(
    x=height_h,
    y=weight_h,
    s=bmi_h * 10,
    c=status_h,
    cmap="jet",
    marker="d",
    alpha=0.5,
)
plt.title("Height vs Weight using bmi for people with normal BMI and Obesity")
plt.legend(["Normal BMI", "Obesity"])
plt.xlabel("height(cm)")
plt.ylabel("weight(kg)")
plt.text(
    152,
    90,
    "Size of marker = bmi \n" "Color of marker = status",
)
plt.colorbar()
plt.show()
